# %% [markdown]
# # Vectorization

# %%
from rasvec import vectorization
from rasterio.plot import show
import rasterio as rio

# %%
ras_path = 'sample_data/raster/ras2.tif'

# %%
ras = rio.open(ras_path)
show(ras)
# Out:
# <Axes: >

# %%
gdf = vectorization(ras_path)

# %%
gdf.plot(facecolor='none', edgecolor='red')
# Out:
# <Axes: >
