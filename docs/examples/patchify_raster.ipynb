# %%
from rasvec import patchify_raster

# %%
patchify_raster(
    raster_path='sample_data/raster/ras.tif', 
    output_path=".", 
    patch_size=256,
    padding=True
)
# Out:
# Saved the patched files in output dir: .
